# %%
# CV Johanna

# %%
pip install --upgrade matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import datetime


def generate_cv_page1():
    plt.figure(figsize=(8.5, 11))  # Set the figure size to letter paper size
    
    # Section presentation
    plt.text(0.5, 0.98, "JOHANNA RIQUELME A", ha='center', va='center', fontsize=16, color='purple', fontweight='bold')
    
    # Address and Phone section
    address_phone_text = "D09P2N3 – Drumcondra | 0899749357"
    plt.text(0.5, 0.95, address_phone_text, ha='center', va='center', fontsize=10)
    
    # Education section
    education_text = "2023094@student.cct.ie - MSc in Data Analytics - CCT College, Ireland"
    plt.text(0.5, 0.93, education_text, ha='center', va='center', fontsize=10)
    
    # LinkedIn section
    linkedin_text = "· linkedin.com/in/johannariquelme"
    GitHub_text = "https://github.com/Johanna23cct/first-project-cv"
    plt.text(0.5, 0.91, linkedin_text, ha='center', va='center', fontsize=10, color='blue')
    plt.text(0.5, 0.89, GitHub_text, ha='center', va='center', fontsize=10, color='blue')
    
    # Add a horizontal line after the Profile section
    plt.axhline(y=0.88, color='black', linewidth=1)
    
    # Professional Profile section
    profile_text = (
        "Professional Profile:\n"
        "With over 20 years of technical support experience.\n"
        "My focus on customer service, technical excellence and SLA management.\n"
        "I encourage continuous improvement. As a bilingual professional,\n"
        "I communicate effectively in two languages, greater market reach.\n"
        "I am dedicated to growth, I seek certifications to stay at the forefront.\n"
        "I am ready to contribute technical expertise and collaborate to drive success.\n"
    )
    plt.text(0.1, 0.87, profile_text, ha='left', va='top', fontsize=10)
    
    # Employment History section (Page 1)
    employment_text = (
        "Employment History:\n"
        "Nov 2022 – Present: Seller, Cinders’s Shoes, Dunnes Stores – Stephen Green\n"
        "   - Retail experience in customer service and expertise\n"
        "   - Consistently achieved top position in seller ranking\n"
        "     I can gladly show if necessary the figures of my accumulated sales for the year.\n"
        "     These numbers speak of my commitment and success in the field.\n"
        "     My tasks include stock control, maintaining products on display, receiving delivery \n"
        "     from the central warehouse and organizing it in the store's internal warehouses,\n"
        "     as well as shipping between stores, customer service and after-sales.\n"
        
        "Sep 2022 – Nov 2022: I was living in Germany\n"
        
        "Oct 2021 – Sep 2022: Gastronomy and Barista Staff, Excel Recruitment and Loss&Co.\n"
        "   - Developed career in gastronomy and customer service\n"
        "   - Worked with major companies such as Guinness Storehouse, Aviva Stadium.\n"
        "   - Obtained FETAC Level 6 Certified Trainer and barista certifications\n"
                        
        "2019 to 2021n"
        "Program Woman Head of Household, project: Kostum2020\n"
        "Position: Entrepreneurship in costume design and tailoring\n"
        "   - Studied Ing at UBO University, through this program\n"
       
        "March 2018 to June 2019\n"
        "CyM SOUTHWEST GAS\n"
        "Position: Administrative processing of collections\n"
        "Preparation of payment statements, input of documentation\n"
        "into the ERP system from Spain, SAP, and Excel databases,\n"
        "and billing using the SII system.\n"

        "December to February 2018\n"
        "MANPOWER Temporary Services\n"
        "Position: Payment Control Administrator at METROGAS S.A.\n"
        "Income, supplier payment management using the SAP system,\n"
        "data extraction to Excel spreadsheets, collaborative tasks with\n"
        "accounting to request invoice payments, and communication\n"
        "with suppliers for payment issuance.\n"

        "January to May 2017\n"
        "Customs Agency BROWNE and Co. Ltd. For Bata Chile S.\n"
        "Position: Foreign Trade Administrative\n"
        "Analysis of accounts for foreign trade suppliers, responsibilities\n"
        "linked to Accounting and Finance, direct communication with suppliers.\n"

        "January to May 2016\n"
        "Freight Forwarders CONFIA CARGO S.A.\n"
        "Position: Operations & Customer-S Dept. (internship for graduation)\n"
        "Creation of importation folders, support for the Operations Department.\n"

        "2009 – 2015: Freelance Art Visual, Owner of Own Project in Work Art\n"
      
        "1989 – 2008: Help Desk, Telephone Support (Level 1) and Laboratory (Level 2)\n"
        "   - Supported various important companies in Chile\n"
        "   - Managed system failures, software and hardware configuration, and reporting\n"
        " I have letters of reference from four of the companies where i worked\n"
        " in this area with which I can demonstrate my experience and functions\n"
        " in more detail if required.\n"
    )
    plt.text(0.1, 0.72, employment_text, ha='left', va='top', fontsize=10)
    
    # Save Page 1
    plt.axis('off')
    plt.savefig('cv_page1.png', dpi=300, bbox_inches='tight')

def generate_cv_page2():
    plt.figure(figsize=(8.5, 11))  # Set the figure size to letter paper size
    
    # Section presentation
    plt.text(0.5, 0.98, "JOHANNA RIQUELME A", ha='center', va='center', fontsize=16, color='purple', fontweight='bold')
    

    
    # Education section
    education_text = "2023094@student.cct.ie - MSc in Data Analytics - 0899749357 - CCT College, Ireland"
    plt.text(0.5, 0.95, education_text, ha='center', va='center', fontsize=10)
    
   # LinkedIn and GitHub section
    linkedin_text = "· linkedin.com/in/johannariquelme"
    GitHub_text = "https://github.com/Johanna23cct/first-project-cv"
    plt.text(0.5, 0.93, linkedin_text, ha='center', va='center', fontsize=10, color='blue')
    plt.text(0.5, 0.91, GitHub_text, ha='center', va='center', fontsize=10, color='blue')
    
    
    # Add a horizontal line after the Profile section
    plt.axhline(y=0.89, color='black', linewidth=1)
    
    # Education & Qualifications section
    education_qualifications_text = (
        "Education & Qualifications:\n\n"
        "February 2023 to June 2024:  MCs Data Analytic, CCT College, Dublin Ireland\n"
        "March 2019:      Business Engineering, University UBO, Chile (Not Graduated)\n"
        "March 2014 to June 2016: Business Administration, CFT Manpower, Chile\n"
        "March 1986 to December 1989: Programmer Technician Diploma, Institute San Luis"
    )
    plt.text(0.1, 0.85, education_qualifications_text, ha='left', va='top', fontsize=10)

    # Specific skills and Competencies section
    Interests_Extra_curricular_text = (
        "Interests / Extra-curricular:\n\n"
        "I have developed volunteer service through Vineyard and\n"
        "volunteer to visits St John of God Hospital, in Dublin\n"
        "I have mastered the art of painting in oil\n"
        "I participated in exhibitions in Chile and Embassy of Chile in Dublin\n"
    )
    plt.text(0.1, 0.71, Interests_Extra_curricular_text, ha='left', va='top', fontsize=10)
    
    # Reference section
    reference_text = (
        "References:\n\n"
        
        "Marguireta Heger\n"
        "Real Estate Consultant at New England Preferred Properties\n"
        "Email: marguireta@marguireta.com\n\n"
        
        "Ms. Sinead Dunne\n"
        "Excel Recruitment\n"
        "Email: Sinead.dunne@excelrecruitment.com\n"
        "Phone: 087 701 2094\n\n"
        
        "Ms. Yeiza Yegres\n"
        "SOUTHWEST CyM Agency\n"
        "Chief of Staff\n"
        "Email: yeiza.yegres@cymsoeste.com\n\n"
    )
    
    plt.text(0.1, 0.57, reference_text, ha='left', va='top', fontsize=10)
    
    # Internships section
    Internships_text = (
    "LOOKING FOR SUMMER INTERNSHIPS & GRADUATE OPPORTUNITIES 2023/2024\n"
    "Employment permit status Stamp 2: Eligible to work 20 hours in term time\n"
    "and full-time over the summer period.\n"
    )
    
    plt.text(0.1, 0.25, Internships_text, ha='left', va='top', fontsize=10)
    
    # Get the current month and year
    current_month = datetime.datetime.now().strftime("%B")
    current_year = datetime.datetime.now().year

    # Add the dynamic date string
    other_text = f"{current_month} {current_year}, Dublin."

    # Now you can use plt.text to display the other_text
    plt.text(0.1, 0.05, other_text, ha='left', va='top', fontsize=10)
   
    # Save Page 2
    plt.axis('off')
    plt.savefig('cv_page2.png', dpi=300, bbox_inches='tight')
    

if __name__ == "__main__":
    generate_cv_page1()
    generate_cv_page2()
